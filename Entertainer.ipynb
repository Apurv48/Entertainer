# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
data1 = pd.read_excel("Entertainer - Basic Info.xlsx")
data2 = pd.read_excel("Entertainer - Breakthrough Info.xlsx")
data3 = pd.read_excel("Entertainer - Last work Info.xlsx")

# %%
data1
# Out:
#         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
# [70 rows x 3 columns]

# %%
data2
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 67     Wayne Newton                                          1972
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#                            Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                         19                           2009.0
# ...

# %%
data3
# Out:
#         Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0             Adele                                2016            NaN
# 1    Angelina Jolie                                2016            NaN
# 2   Aretha Franklin                                2014            NaN
# 3       Bette Davis                                1989         1989.0
# 4       Betty White                                2016            NaN
# ..              ...                                 ...            ...
# 65        Tom Hanks                                2016            NaN
# 66     Tony Bennett                                2016            NaN
# 67     Wayne Newton                                2016            NaN
# 68       Will Smith                                2016            NaN
# 69    Willie Nelson                                2016            NaN
#
# [70 rows x 3 columns]

# %%
data1.isnull()
# Out:
#     Entertainer  Gender (traditional)  Birth Year
# 0         False                 False       False
# 1         False                 False       False
# 2         False                 False       False
# 3         False                 False       False
# 4         False                 False       False
# ..          ...                   ...         ...
# 65        False                 False       False
# 66        False                 False       False
# 67        False                 False       False
# 68        False                 False       False
# 69        False                 False       False
#
# [70 rows x 3 columns]

# %%
data2.isnull()
# Out:
#     Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0         False                                         False
# 1         False                                         False
# 2         False                                         False
# 3         False                                         False
# 4         False                                         False
# ..          ...                                           ...
# 65        False                                         False
# 66        False                                         False
# 67        False                                         False
# 68        False                                         False
# 69        False                                         False
#
#     Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0               False                            False
# 1               False                            False
# ...

# %%
data3.isnull()
# Out:
#     Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0         False                               False           True
# 1         False                               False           True
# 2         False                               False           True
# 3         False                               False          False
# 4         False                               False           True
# ..          ...                                 ...            ...
# 65        False                               False           True
# 66        False                               False           True
# 67        False                               False           True
# 68        False                               False           True
# 69        False                               False           True
#
# [70 rows x 3 columns]

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=70, step=1)

# %%
data1.columns
# Out:
# Index(['Entertainer', 'Gender (traditional)', 'Birth Year'], dtype='object')

# %%
data1.dtypes
# Out:
# Entertainer             object
# Gender (traditional)    object
# Birth Year               int64
# dtype: object

# %%
data2.index
# Out:
# RangeIndex(start=0, stop=70, step=1)

# %%
data2.columns
# Out:
# Index(['Entertainer', 'Year of Breakthrough/#1 Hit/Award Nomination',
#        'Breakthrough Name', 'Year of First Oscar/Grammy/Emmy'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# Entertainer                                      object
# Year of Breakthrough/#1 Hit/Award Nomination      int64
# Breakthrough Name                                object
# Year of First Oscar/Grammy/Emmy                 float64
# dtype: object

# %%
data2.count()
# Out:
# Entertainer                                     70
# Year of Breakthrough/#1 Hit/Award Nomination    70
# Breakthrough Name                               70
# Year of First Oscar/Grammy/Emmy                 64
# dtype: int64

# %%
data2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# Length: 70, dtype: bool

# %%
data1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# Length: 70, dtype: bool

# %%
data2.isna()
# Out:
#     Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0         False                                         False
# 1         False                                         False
# 2         False                                         False
# 3         False                                         False
# 4         False                                         False
# ..          ...                                           ...
# 65        False                                         False
# 66        False                                         False
# 67        False                                         False
# 68        False                                         False
# 69        False                                         False
#
#     Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0               False                            False
# 1               False                            False
# ...

# %%
data1.isna()
# Out:
#     Entertainer  Gender (traditional)  Birth Year
# 0         False                 False       False
# 1         False                 False       False
# 2         False                 False       False
# 3         False                 False       False
# 4         False                 False       False
# ..          ...                   ...         ...
# 65        False                 False       False
# 66        False                 False       False
# 67        False                 False       False
# 68        False                 False       False
# 69        False                 False       False
#
# [70 rows x 3 columns]

# %%
data1.describe()
# Out:
#         Birth Year
# count    70.000000
# mean   1935.585714
# std      24.135783
# min    1889.000000
# 25%    1916.000000
# 50%    1935.500000
# 75%    1954.000000
# max    1988.000000

# %%
data2.describe()
# Out:
#        Year of Breakthrough/#1 Hit/Award Nomination  \
# count                                     70.000000
# mean                                    1964.228571
# std                                       22.411935
# min                                     1915.000000
# 25%                                     1949.500000
# 50%                                     1963.500000
# 75%                                     1983.500000
# max                                     2008.000000
#
#        Year of First Oscar/Grammy/Emmy
# count                        64.000000
# mean                       1976.234375
# std                          22.170152
# min                        1929.000000
# 25%                        1962.000000
# 50%                        1978.000000
# 75%                        1993.000000
# max                        2017.000000

# %%
data3.describe()
# Out:
#        Year of Last Major Work (arguable)  Year of Death
# count                           70.000000      30.000000
# mean                          1998.971429    1988.133333
# std                             22.874561      20.483355
# min                           1933.000000    1942.000000
# 25%                           1980.000000    1977.000000
# 50%                           2014.000000    1989.500000
# 75%                           2016.000000    2003.750000
# max                           2016.000000    2016.000000

# %%
data1.values
# Out:
# array([['Adele', 'F', 1988],
#        ['Angelina Jolie', 'F', 1975],
#        ['Aretha Franklin', 'F', 1942],
#        ['Bette Davis', 'F', 1908],
#        ['Betty White', 'F', 1922],
#        ['Bing Crosby', 'M', 1903],
#        ['Bob Hope', 'M', 1903],
#        ['Carol Burnett', 'F', 1933],
#        ['Carole Lombard', 'F', 1908],
#        ['Carrie Fisher', 'F', 1956],
#        ['Cary Grant', 'M', 1904],
#        ['Charlie Chaplin', 'M', 1889],
#        ['Clara Bow', 'F', 1905],
#        ['Clark Gable', 'M', 1901],
#        ['David Letterman', 'M', 1947],
#        ['Debbie Reynolds', 'F', 1932],
#        ['Denzel Washington', 'M', 1954],
#        ['Dick Van Dyke', 'M', 1925],
#        ['Donald Sutherland', 'M', 1935],
#        ['Dustin Hoffman', 'M', 1937],
#        ['Ed Sullivan', 'M', 1901],
#        ['Eddie Murphy', 'M', 1961],
#        ['Elton John', 'M', 1947],
#        ['Elvis Presley', 'M', 1935],
#        ['Frank Sinatra', 'M', 1915],
#        ['Gene Hackman', 'M', 1930],
# ...

# %%
data2.values
# Out:
# array([['Adele', 2008, 19, 2009.0],
#        ['Angelina Jolie', 1999, 'Girl, Interrupted', 1999.0],
#        ['Aretha Franklin', 1967,
#         'I Never Loved a Man (The Way I Love You)', 1968.0],
#        ['Bette Davis', 1934, 'Of Human Bondage', 1935.0],
#        ['Betty White', 1952, 'Life with Elilzabeth', 1976.0],
#        ['Bing Crosby', 1931, 'Several Songs', 1962.0],
#        ['Bob Hope', 1938, 'The Big Broadcast of 1938', 1940.0],
#        ['Carol Burnett', 1959, 'The Garry Moore Show', 1962.0],
#        ['Carole Lombard', 1934, 'Twentieth Century', nan],
#        ['Carrie Fisher', 1977, 'Star Wars', nan],
#        ['Cary Grant', 1933, "She Done Him Wrong, I'm No Angel", 1970.0],
#        ['Charlie Chaplin', 1915, 'The Tramp', 1929.0],
#        ['Clara Bow', 1926, 'Mantrap', nan],
#        ['Clark Gable', 1934, 'It Happened One Night', 1934.0],
#        ['David Letterman', 1982, 'Late Night with David Letterman',
#         1981.0],
# ...

# %%
data3.values
# Out:
# array([['Adele', 2016, nan],
#        ['Angelina Jolie', 2016, nan],
#        ['Aretha Franklin', 2014, nan],
#        ['Bette Davis', 1989, 1989.0],
#        ['Betty White', 2016, nan],
#        ['Bing Crosby', 1974, 1977.0],
#        ['Bob Hope', 1972, 2003.0],
#        ['Carol Burnett', 2016, nan],
#        ['Carole Lombard', 1942, 1942.0],
#        ['Carrie Fisher', 2016, 2016.0],
#        ['Cary Grant', 1966, 1986.0],
#        ['Charlie Chaplin', 1967, 1977.0],
#        ['Clara Bow', 1933, 1965.0],
#        ['Clark Gable', 1960, 1960.0],
#        ['David Letterman', 2015, nan],
#        ['Debbie Reynolds', 2006, 2016.0],
#        ['Denzel Washington', 2016, nan],
#        ['Dick Van Dyke', 2015, nan],
#        ['Donald Sutherland', 2016, nan],
#        ['Dustin Hoffman', 2016, nan],
#        ['Ed Sullivan', 1973, 1974.0],
#        ['Eddie Murphy', 2016, nan],
#        ['Elton John', 2016, nan],
#        ['Elvis Presley', 1977, 1977.0],
#        ['Frank Sinatra', 1980, 1998.0],
# ...

# %%
data1.iterrows
# Out:
# <bound method DataFrame.iterrows of         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
# [70 rows x 3 columns]>

# %%
data1.head(15)
# Out:
#         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# 5       Bing Crosby                    M        1903
# 6          Bob Hope                    M        1903
# 7     Carol Burnett                    F        1933
# 8    Carole Lombard                    F        1908
# 9     Carrie Fisher                    F        1956
# 10       Cary Grant                    M        1904
# 11  Charlie Chaplin                    M        1889
# 12        Clara Bow                    F        1905
# 13      Clark Gable                    M        1901
# 14  David Letterman                    M        1947

# %%
data2.head(15)
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# 5       Bing Crosby                                          1931
# 6          Bob Hope                                          1938
# 7     Carol Burnett                                          1959
# 8    Carole Lombard                                          1934
# 9     Carrie Fisher                                          1977
# 10       Cary Grant                                          1933
# 11  Charlie Chaplin                                          1915
# 12        Clara Bow                                          1926
# ...

# %%
data3.head(15)
# Out:
#         Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0             Adele                                2016            NaN
# 1    Angelina Jolie                                2016            NaN
# 2   Aretha Franklin                                2014            NaN
# 3       Bette Davis                                1989         1989.0
# 4       Betty White                                2016            NaN
# 5       Bing Crosby                                1974         1977.0
# 6          Bob Hope                                1972         2003.0
# 7     Carol Burnett                                2016            NaN
# 8    Carole Lombard                                1942         1942.0
# 9     Carrie Fisher                                2016         2016.0
# 10       Cary Grant                                1966         1986.0
# 11  Charlie Chaplin                                1967         1977.0
# ...

# %%
data3['Year of Last Major Work (arguable)'].head()
# Out:
# 0    2016
# 1    2016
# 2    2014
# 3    1989
# 4    2016
# Name: Year of Last Major Work (arguable), dtype: int64

# %%
data3['Year of Death'].dtypes
# Out:
# dtype('float64')

# %%
data3['Year of Last Major Work (arguable)'].dtypes
# Out:
# dtype('int64')

# %%
data3['Year of Death'].convert_dtypes()
# Out:
# 0     <NA>
# 1     <NA>
# 2     <NA>
# 3     1989
# 4     <NA>
#       ...
# 65    <NA>
# 66    <NA>
# 67    <NA>
# 68    <NA>
# 69    <NA>
# Name: Year of Death, Length: 70, dtype: Int64

# %%
data3['Year of Death'].dtypes
# Out:
# dtype('float64')

# %%
data1.loc[0]
# Out:
# Entertainer             Adele
# Gender (traditional)        F
# Birth Year               1988
# Name: 0, dtype: object

# %%
data1.ndim
# Out:
# 2

# %%
data1.count()
# Out:
# Entertainer             70
# Gender (traditional)    70
# Birth Year              70
# dtype: int64

# %%
for i in range(70):
    print(data1.loc[i])
# Out:
# Entertainer             Adele
# Gender (traditional)        F
# Birth Year               1988
# Name: 0, dtype: object
# Entertainer             Angelina Jolie
# Gender (traditional)                 F
# Birth Year                        1975
# Name: 1, dtype: object
# Entertainer             Aretha Franklin
# Gender (traditional)                  F
# Birth Year                         1942
# Name: 2, dtype: object
# Entertainer             Bette Davis
# Gender (traditional)              F
# Birth Year                     1908
# Name: 3, dtype: object
# Entertainer             Betty White
# Gender (traditional)              F
# Birth Year                     1922
# Name: 4, dtype: object
# Entertainer             Bing Crosby
# Gender (traditional)              M
# Birth Year                     1903
# Name: 5, dtype: object
# Entertainer             Bob Hope
# Gender (traditional)           M
# Birth Year                  1903
# Name: 6, dtype: object
# ...

# %%
data = data1.merge(data2,on='Entertainer')

# %%
data
# Out:
#         Entertainer Gender (traditional)  Birth Year  \
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
#     Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                           2008
# 1                                           1999
# 2                                           1967
# 3                                           1934
# 4                                           1952
# ...

# %%
data = data.merge(data3, on='Entertainer')

# %%
data
# Out:
#         Entertainer Gender (traditional)  Birth Year  \
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
#     Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                           2008
# 1                                           1999
# 2                                           1967
# 3                                           1934
# 4                                           1952
# ...

# %%
x=data['Entertainer'].tail()
y=data['Year of Breakthrough/#1 Hit/Award Nomination'].tail()
size=200
color= np.random.uniform(15, 80, len(x))
plt.scatter(x,y,s=size,c=color, vmin=0,vmax=100)
plt.show()

# %%
x=data['Year of Breakthrough/#1 Hit/Award Nomination']
y=data['Year of First Oscar/Grammy/Emmy']
plt.plot(x,y)
plt.show()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entertainer           70 non-null     object
#  1   Gender (traditional)  70 non-null     object
#  2   Birth Year            70 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.8+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Year of Breakthrough/#1 Hit/Award Nomination  70 non-null     int64
#  2   Breakthrough Name                             70 non-null     object
#  3   Year of First Oscar/Grammy/Emmy               64 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.3+ KB

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Entertainer                         70 non-null     object
#  1   Year of Last Major Work (arguable)  70 non-null     int64
#  2   Year of Death                       30 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Gender (traditional)                          70 non-null     object
#  2   Birth Year                                    70 non-null     int64
#  3   Year of Breakthrough/#1 Hit/Award Nomination  70 non-null     int64
#  4   Breakthrough Name                             70 non-null     object
#  5   Year of First Oscar/Grammy/Emmy               64 non-null     float64
#  6   Year of Last Major Work (arguable)            70 non-null     int64
#  7   Year of Death                                 30 non-null     float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 4.5+ KB

# %%
data.describe()
# Out:
#         Birth Year  Year of Breakthrough/#1 Hit/Award Nomination  \
# count    70.000000                                     70.000000
# mean   1935.585714                                   1964.228571
# std      24.135783                                     22.411935
# min    1889.000000                                   1915.000000
# 25%    1916.000000                                   1949.500000
# 50%    1935.500000                                   1963.500000
# 75%    1954.000000                                   1983.500000
# max    1988.000000                                   2008.000000
#
#        Year of First Oscar/Grammy/Emmy  Year of Last Major Work (arguable)  \
# count                        64.000000                           70.000000
# mean                       1976.234375                         1998.971429
# std                          22.170152                           22.874561
# min                        1929.000000                         1933.000000
# ...

# %%
data['Breakthrough Name']= data['Breakthrough Name'].astype("string")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Gender (traditional)                          70 non-null     object
#  2   Birth Year                                    70 non-null     int64
#  3   Year of Breakthrough/#1 Hit/Award Nomination  70 non-null     int64
#  4   Breakthrough Name                             70 non-null     string
#  5   Year of First Oscar/Grammy/Emmy               64 non-null     float64
#  6   Year of Last Major Work (arguable)            70 non-null     int64
#  7   Year of Death                                 30 non-null     float64
# dtypes: float64(2), int64(3), object(2), string(1)
# memory usage: 4.5+ KB

# %%
data[['Entertainer','Breakthrough Name']]
# Out:
#         Entertainer                         Breakthrough Name
# 0             Adele                                        19
# 1    Angelina Jolie                         Girl, Interrupted
# 2   Aretha Franklin  I Never Loved a Man (The Way I Love You)
# 3       Bette Davis                          Of Human Bondage
# 4       Betty White                      Life with Elilzabeth
# ..              ...                                       ...
# 65        Tom Hanks                                    Splash
# 66     Tony Bennett                            Because of You
# 67     Wayne Newton             Daddy, Don't You Walk So Fast
# 68       Will Smith               The Fresh Prince of Bel-Air
# 69    Willie Nelson                       Red Headed Stranger
#
# [70 rows x 2 columns]

# %%
data[['Entertainer','Birth Year','Year of Breakthrough/#1 Hit/Award Nomination']]
# Out:
#         Entertainer  Birth Year  Year of Breakthrough/#1 Hit/Award Nomination
# 0             Adele        1988                                          2008
# 1    Angelina Jolie        1975                                          1999
# 2   Aretha Franklin        1942                                          1967
# 3       Bette Davis        1908                                          1934
# 4       Betty White        1922                                          1952
# ..              ...         ...                                           ...
# 65        Tom Hanks        1956                                          1984
# 66     Tony Bennett        1926                                          1951
# 67     Wayne Newton        1942                                          1972
# 68       Will Smith        1968                                          1990
# 69    Willie Nelson        1933                                          1975
#
# [70 rows x 3 columns]

# %%
data[['Entertainer','Year of Breakthrough/#1 Hit/Award Nomination','Year of First Oscar/Grammy/Emmy']]
# Out:
#         Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0             Adele                                          2008
# 1    Angelina Jolie                                          1999
# 2   Aretha Franklin                                          1967
# 3       Bette Davis                                          1934
# 4       Betty White                                          1952
# ..              ...                                           ...
# 65        Tom Hanks                                          1984
# 66     Tony Bennett                                          1951
# 67     Wayne Newton                                          1972
# 68       Will Smith                                          1990
# 69    Willie Nelson                                          1975
#
#     Year of First Oscar/Grammy/Emmy
# 0                            2009.0
# 1                            1999.0
# 2                            1968.0
# ...
